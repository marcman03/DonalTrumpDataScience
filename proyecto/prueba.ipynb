# %%
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
X = pandas.read_csv('X.csv', sep=',', na_values="")
y = pandas.read_csv('y.csv', sep=',', na_values="")
print(X.shape)
print(y.shape)
# Out:
# (7375, 1477)
# (7375, 1)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score, train_test_split
import sklearn.neighbors as nb


# Configuración de la validación cruzada
(X_train, X_test,  y_train, y_test) = train_test_split(X, y, test_size=.3, random_state=1)

# Inicializar el clasificador Naive Bayes
mnb = MultinomialNB()

for train_index, test_index in kf.split(X_train, y_train):
    # Seleccionamos las filas correspondientes
    X_train2, X_test2 = X.iloc[train_index], X.iloc[test_index]
    y_train2, y_test2 = y[train_index], y[test_index]

    # Entrenamos el modelo
    clf.fit(X_train2, y_train2)
    probs = clf.predict_proba(X_test2)
    ProbClass1 = probs[:, 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      10 # Inicializar el clasificador Naive Bayes
#      11 mnb = MultinomialNB()
# ---> 13 for train_index, test_index in kf.split(X_train, y_train):
#      14     # Seleccionamos las filas correspondientes
#      15     X_train2, X_test2 = X.iloc[train_index], X.iloc[test_index]
#      16     y_train2, y_test2 = y[train_index], y[test_index]
#
# NameError: name 'kf' is not defined
